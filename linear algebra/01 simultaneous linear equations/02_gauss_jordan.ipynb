# %% [markdown]
# # Gauss-Jordan 消去法
# - ガウス・ジョルダン

# %% [markdown]
# ### <u>消去法の種類</u>
#
# <center>
# <u>Gauss-Jordanの消去法</u><br>
#     <br>
# <b>完全前進消去</b><br>
# </center>
#
# <center>
#     <br>
# <u>Gaussの消去法</u><br>
#     <br>
# <b>前進消去　+　後退代入</b>
# </center>

# %% [markdown]
# ### <u>式変形</u>
# - **式全体に適切な定数を掛ける**
#
# - **ある式に別の式の定数倍を足す、あるいは引く**
#
# - **(式を並べる順番を交換する)**

# %% [markdown]
# ## **一般的な連立一次方程式**
# - **添え字付きの変数の使用**
#     - *index とも言う*
#
#
# ### <u>添え字付き変数</u>
#
# - $n$個の添え字付き変数
#     - **変動する値**
# $$x_1,　x_2,　x_3,　...,　x_n$$
#
#
# - $n$個の添え字付き変数の合計
# $$
# x_1　+　x_2　+　...　+　x_n　=　\sum_{i=1}^n x_i
# $$
#
#
# - $m$個の添え字付き定数
#     - **定まった値**
# $$
# b_1,　b_2,　...　,bm
# $$
#
#
# - **二重の添え字付き定数**
#
# #### $$
# a_{ij}　(i　=　1,　...,　m,　j　=　1,　...,　n)
# $$
#
# - 具体的には　**$a_{12}$**　と記述するが...
#     - これは　`12番目`　の添え字付き定数では無いので注意！！
#         - **$i = 1, j = 2$ の定数**
# $$
# i　=　1,　j　=　2
# $$
#
# - *二重添え字を明確にする場合は, $a_{1,2}$ と記述する場合もある*

# %% [markdown]
# ## **変数と式の個数**
# - *変数の個数と式の個数の関係は, 連立方程式の解を特徴づけるヒントがある*
#
# ### *例）*
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & 2x-2y-4z=-6 & ...(1) \\
#     & 3x-y+4z=-7 & ...(2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-z=-2 & ...(1^{''})\\
#     & y+z=1 & ...(2^{''})\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# - *任意の paramertor　**$s$**　を導入し　**$z = s$**　とする*
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x=s-2 & ...(1^{'''})\\
#     & y=-s+1 & ...(2^{'''})\\
#     & z=s & ...(3)
#     \end{aligned}
# \right.
# \end{equation}
# $$

# %% [markdown]
# ### <u>自由パラメーター</u>
# - どうして自由パラメーターを導入したか？
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-z=-2 \\
#     & y+z=1 \\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# - *連立方程式の最終形を見ると*
#
#     - **変数　:　3個**
#     - **方程式　:　2個**
#
#         - `その差である１`　がこの方程式の自由度
#         - *式において　$z$　に値を与えると　$x,　y$　の値が決定する*
#         - *これは　$x,　y$　に値を与えても同様に他の値が決定する*
#
# <center><br>
#     <b>自由度の個数分の paramertor を与える事ができる</b>
# </center>

# %% [markdown]
# ### **解についての考察**
# - *$s$　は任意の実数なので、解は無限にある*
#
# #### $$
# (　x,　y,　z　)　=　( s - 2,　-s + 1,　s )
# $$
#
#
# |s|x|y|z|
# |:---:|:---:|:---:|:---:|
# |0|-2|1|0|
# |1|-1|0|1|
# |2|0|-1|2|
# |...|...|...|...|
#
#
# <center><br>
#     <br>
#   <b>式の個数が変数の個数より少ない場合,方程式の解が無限にある可能性がわかる</b><br>
#     <br>
# </center>

# %% [markdown]
# ## **連立一次方程式の解のパターン**
# - *３種類のパターンがある*
#
# <center><br>
#     <br>
#     <b>解が一意的に存在するケース</b>
#     <br>
#     <br>
#     <b>解が無限に存在するケース</b>
#     <br>
#     <br>
#     <b>解が存在しないケース</b>
#     <br>
# </center>

# %% [markdown]
# ### 【a】
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(a1) \\
#     & 2x-3y=1 & ...(a2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# ### 【b】
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(b1) \\
#     & 2x+6y=10 & ...(b2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# ### 【c】
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(c1) \\
#     & 2x+6y=5 & ...(c2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$

# %% [markdown]
# ### 【a】の解を求める
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(a1) \\
#     & 2x-3y=1 & ...(a2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(a1) \\
#     & -9y=-9 & ...(a2^{'}) &　=　(a2)-2(a1)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(a1) \\
#     & y=1 & ...(a2^{''}) &　=　\frac{(a2^{'})}{(-9)}\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# <center>
#     <br>
#     <br>
#     <b>解が一意的に存在するケース</b>
#     <br>
#     <br>
# </center>
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x=2 & ...(a1^{'}) \\
#     & y=1 & ...(a2^{''})\\
#     \end{aligned}
# \right.
# \end{equation}
# $$

# %% [markdown]
# ## 【b】の解を求める
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(b1) \\
#     & 2x+6y=10 & ...(b2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(b1) \\
#     & 0=0 & ...(b2^{'}) &　=　(b2)-2(b1)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# - **式　($b2^{'}$)　は変数を含まない恒等式なので,実質きは　$(b1)$　だけ**
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(b1) \\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# - **任意の paramertor として　$y=s$　とおく**
#
# <center><br>
#     <br>
#     <b>解が無限に存在するケース</b>
#     <br>
#     <br>
# </center>
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x=5-3s & ...(b1^{'}) \\
#     & y=s & ...(b3) \\
#     \end{aligned}
# \right.
# \end{equation}
# $$

# %% [markdown]
# ## 【c】の解を求める
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(c1) \\
#     & 2x+6y=5 & ...(c2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# <center>
#     <br>
#     <b>解が存在しないケース</b>
#     <br>
#     <br>
# </center>
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(c1) \\
#     & 0=-5 & ...(c2^{'}) &　=　2(c1)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
# - **明らかに矛盾しているのでこの連立方程式を満たさない**

# %% [markdown]
# ## **解の幾何学的解釈**

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 【a】　解が一意的に存在するケース
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(a1) \\
#     & 2x-3y=1 & ...(a2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# - **それぞれの⽅程式を直線を表す式として⾒慣れた$y=ax+b$の形に変形**
#
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & y=-\frac{1}{3}x+\frac{5}{3} & ...(a1^{'}) \\
#     & y=\frac{2}{3}x-\frac{1}{3} & ...(a2^{'})\\
#     \end{aligned}
# \right.
# \end{equation}
# $$

# %%
left = [0, 6]
eq1 = [5/3, -1/3]
eq2 = [-1/3, 11/3]
plt.plot(left, eq1, color='b', label='x+3y=5')
plt.plot(left, eq2, color='r', label='2x-3y=1')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %% [markdown]
# - **２本の直線が１点で交差している。したがって、解はその１点のみとなる**

# %% [markdown]
# ### 【b】　解が無限に存在するケース
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(b1) \\
#     & 2x+6y=10 & ...(b2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# - **それぞれの⽅程式を直線を表す式として⾒慣れた$y=ax+b$の形に変形**
#
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & y=-\frac{1}{3}x+\frac{5}{3} & ...(b1^{'}) \\
#     & y=-\frac{1}{3}x-\frac{5}{3} & ...(b2^{'})\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# - **このように両方の式が全く同じ式になっている**

# %%
left = [0, 6]
eq1 = [5/3, -1/3]
eq2 = [5/3, -1/3]
plt.plot(left, eq1, color='b', label='x+3y=5')
plt.plot(left, eq2, color='r', linestyle='dotted', linewidth=3, label='2x-6y=10')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %% [markdown]
# - **２つの直線は全く一致している。この直線上の全てが連立方程式の解となっている**

# %% [markdown]
# ### 【c】　解が存在しないケース
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & x-3y=5 & ...(c1) \\
#     & 2x+6y=5 & ...(c2)\\
#     \end{aligned}
# \right.
# \end{equation}
# $$
#
#
# - **それぞれの⽅程式を直線を表す式として⾒慣れた$y=ax+b$の形に変形**
#
#
# $$
# \begin{equation}
# \left\{ \,
#     \begin{aligned}
#     & y=-\frac{1}{3}x+\frac{5}{3} & ...(c1^{'}) \\
#     & y=-\frac{1}{3}x-\frac{5}{6} & ...(c2^{'})\\
#     \end{aligned}
# \right.
# \end{equation}
# $$

# %%
left = [0, 6]
eq1 = [5/3, -1/3]
eq2 = [5/6, -7/6]
plt.plot(left, eq1, color='b', label='x+3y=5')
plt.plot(left, eq2, color='r', label='2x-6y=5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %% [markdown]
# - **２つの直線は平行線である。したがって両方の方程式を満たす点が存在しない事を幾何学的に説明している。解は無いという事になる**

# %% [markdown]
# <center><br>
#   連立方程式は平面上の２直線の位置関係を表している事がわかる<br>
#     <br>
# </center>
#
# |連立方程式|幾何学的状況(2次元の場合)|
# |:---:|:---:|
# |解が存在して,一意的である|2つの方て式が表す直線の交点|
# |解は存在するが,無限個ある|2つの方程式の直線が重なり合う|
# |解が存在しない|2つの方程式の直線が平行線となる|
